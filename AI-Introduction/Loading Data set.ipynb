# %% [markdown]
# #Connect To Google drive

# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %% [markdown]
# Move to folder

# %%
# %cd "/content/gdrive/My Drive/Cursos/IA (Sistemas Inteligentes)/English Feb Jun/Content/1 Intro to AI"
# !ls
# Out:
# /content/gdrive/My Drive/Cursos/IA (Sistemas Inteligentes)/English Feb Jun/Content/1 Intro to AI
#  iris.data   'Loading Data set.ipynb'  'Visualizing a Data.ipynb'   wine.names
#  iris.names  'Origins of A.I..gdoc'     wine.data

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd

#the file has no names for columns.
columns = ["sepal length","sepal width","petal length","petal width", "class"]
df = pd.read_csv('iris.data',names = columns)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %% [markdown]
# get a single column you wish

# %%
df["sepal length"]
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
#       ...
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sepal length, Length: 149, dtype: float64

# %% [markdown]
# get many columns

# %%
df[["sepal length","sepal width"]]
# Out:
#      sepal length  sepal width
# 0             4.9          3.0
# 1             4.7          3.2
# 2             4.6          3.1
# 3             5.0          3.6
# 4             5.4          3.9
# ..            ...          ...
# 144           6.7          3.0
# 145           6.3          2.5
# 146           6.5          3.0
# 147           6.2          3.4
# 148           5.9          3.0
#
# [149 rows x 2 columns]

# %%
df_x = df[["sepal length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           4.6          3.1           1.5          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %%
df_y.head()
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# make new columns with indicators

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepal length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepal length  sepal width  ...  sepal proportion  petal proportion
# 0           4.9          3.0  ...          0.612245          0.142857
# 1           4.7          3.2  ...          0.680851          0.153846
# 2           4.6          3.1  ...          0.673913          0.133333
# 3           5.0          3.6  ...          0.720000          0.142857
# 4           5.4          3.9  ...          0.722222          0.235294
#
# [5 rows x 6 columns]
